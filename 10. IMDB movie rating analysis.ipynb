# %%
#IMDB MOVIE RATING ANALYSIS

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
movies= pd.read_csv("movies.csv")

# %%
#Data Cleaning: Handling Missing Data

# %%
movies.shape
# Out:
# (45843, 3)

# %%
movies.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
movies= pd.read_csv("movies.csv", sep=',')

# %%
movies.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
movies.isnull()
# Out:
#        movieId  title  genres
# 0        False  False   False
# 1        False  False   False
# 2        False  False   False
# 3        False  False   False
# 4        False  False   False
# ...        ...    ...     ...
# 45838    False  False   False
# 45839    False  False   False
# 45840    False  False   False
# 45841    False  False   False
# 45842    False  False   False
#
# [45843 rows x 3 columns]

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
movies.isnull().any().any()
# Out:
# False

# %%
ratings= pd.read_csv("ratings.csv")

# %%
ratings.shape
# Out:
# (26024289, 4)

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.tail()
# Out:
#           userId  movieId  rating   timestamp
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858

# %%
tags= pd.read_csv("tags.csv")

# %%
tags.shape
# Out:
# (753170, 4)

# %%
tags.head()
# Out:
#    userId  movieId         tag   timestamp
# 0       1      318    narrated  1425942391
# 1      20     4306  Dreamworks  1459855607
# 2      20    89302     England  1400778834
# 3      20    89302   espionage  1400778836
# 4      20    89302        jazz  1400778841

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
row_0 = tags.iloc[0]
type(row_0)
# Out:
# pandas.core.series.Series

# %%
print(row_0)
# Out:
# userId            1
# movieId         318
# tag        narrated
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
#DataFrames

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=753170, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[ [0,11,500] ]
# Out:
#      userId  movieId       tag
# 0         1      318  narrated
# 11       20   113315    satire
# 500     674     3000      dark

# %%
#Descriptive Statistics

# %%
ratings['rating'].describe()
# Out:
# count    2.602429e+07
# mean     3.528090e+00
# std      1.065443e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.602429e+07  2.602429e+07  2.602429e+07
# mean   1.350371e+05  1.584911e+04  3.528090e+00
# std    7.817620e+04  3.108526e+04  1.065443e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    6.716400e+04  1.073000e+03  3.000000e+00
# 50%    1.351630e+05  2.583000e+03  3.500000e+00
# 75%    2.026930e+05  6.503000e+03  4.000000e+00
# max    2.708960e+05  1.762750e+05  5.000000e+00

# %%
ratings['rating'].mean()
# Out:
# 3.5280903543608817

# %%
ratings.mean()
# Out:
# userId     135037.090248
# movieId     15849.109677
# rating          3.528090
# dtype: float64

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].std()
# Out:
# 1.0654427637644484

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.001410 -0.000159
# movieId -0.001410  1.000000 -0.002841
# rating  -0.000159 -0.002841  1.000000

# %%
filter1 = ratings['rating'] > 5
print(filter1)
filter1.any()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 26024284    False
# 26024285    False
# 26024286    False
# 26024287    False
# 26024288    False
# Name: rating, Length: 26024289, dtype: bool
# False

# %%
#Data visualization

# %%
# %matplotlib inline

# %%
ratings.hist(column='rating',figsize=(8,4))
# Out:
# array([[<AxesSubplot:title={'center':'rating'}>]], dtype=object)

# %%
ratings.boxplot(column='rating',figsize=(8,4))
# Out:
# <AxesSubplot:>

# %%
#slicing out column

# %%
tags['tag'].head()
# Out:
# 0      narrated
# 1    Dreamworks
# 2       England
# 3     espionage
# 4          jazz
# Name: tag, dtype: object

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 26024279  270896    54286     4.5
# 26024280  270896    54503     4.0
# 26024281  270896    55820     5.0
# 26024282  270896    56174     3.5
# 26024283  270896    56367     4.5
# 26024284  270896    58559     5.0
# 26024285  270896    60069     5.0
# 26024286  270896    63082     4.5
# 26024287  270896    64957     4.5
# 26024288  270896    71878     2.0

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-10:]
# Out:
# Interracial Friendship    1
# Punks                     1
# Sexual Slavery            1
# Glue Sniffing             1
# Abandonment               1
# Virgin                    1
# Stuttering                1
# Male Nudity               1
# Disability                1
# Gael GarcÃ?Â­a Bernal     1
# Name: tag, dtype: int64

# %%
tag_counts[:10].plot(kind='bar', figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
#Filters for Selecting Rows

# %%
is_highly_rated = ratings['rating'] >= 5.0
ratings[is_highly_rated][10:20]
# Out:
#     userId  movieId  rating
# 19       1    81834     5.0
# 21       1    91542     5.0
# 22       1    92439     5.0
# 23       1    96821     5.0
# 26       1   112552     5.0
# 35       2      339     5.0
# 46       2     1356     5.0
# 62       4     1097     5.0
# 65       4     1221     5.0
# 75       4     2023     5.0

# %%
is_action= movies['genres'].str.contains('Action')
movies[is_action][5:15]
# Out:
#     movieId                                      title  \
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
# 69       70                 From Dusk Till Dawn (1996)
# 70       71                           Fair Game (1995)
# 75       76                           Screamers (1995)
# 77       78                 Crossing Guard, The (1995)
# 85       86                        White Squall (1996)
#
#                            genres
# 22          Action|Crime|Thriller
# 41             Action|Crime|Drama
# 43       Action|Adventure|Fantasy
# 50          Action|Drama|Thriller
# 65         Action|Sci-Fi|Thriller
# 69  Action|Comedy|Horror|Thriller
# 70                         Action
# 75         Action|Sci-Fi|Thriller
# 77    Action|Crime|Drama|Thriller
# 85         Action|Adventure|Drama

# %%
movies[is_action].head(10)
# Out:
#     movieId                                      title  \
# 5         6                                Heat (1995)
# 8         9                        Sudden Death (1995)
# 9        10                           GoldenEye (1995)
# 14       15                    Cutthroat Island (1995)
# 19       20                         Money Train (1995)
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
#
#                                 genres
# 5                Action|Crime|Thriller
# 8                               Action
# 9            Action|Adventure|Thriller
# 14            Action|Adventure|Romance
# 19  Action|Comedy|Crime|Drama|Thriller
# 22               Action|Crime|Thriller
# 41                  Action|Crime|Drama
# 43            Action|Adventure|Fantasy
# 50               Action|Drama|Thriller
# 65              Action|Sci-Fi|Thriller

# %%
#Group By and Aggregate

# %%
ratings_count = ratings[['movieId','rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5      404897
# 1.0      843310
# 1.5      403607
# 2.0     1762440
# 2.5     1255358
# 3.0     5256722
# 3.5     3116213
# 4.0     6998802
# 4.5     2170441
# 5.0     3812499

# %%
average_rating = ratings[['movieId','rating']].groupby('movieId').mean()
average_rating.head()
# Out:
#            rating
# movieId
# 1        3.888157
# 2        3.236953
# 3        3.175550
# 4        2.875713
# 5        3.079565

# %%
movie_count = ratings[['movieId','rating']].groupby('movieId').count()
movie_count.tail()
# Out:
#          rating
# movieId
# 176267        1
# 176269        1
# 176271        1
# 176273        1
# 176275        1

# %%
#Merge Dataframes

# %%
tags.head()
# Out:
#    userId  movieId         tag
# 0       1      318    narrated
# 1      20     4306  Dreamworks
# 2      20    89302     England
# 3      20    89302   espionage
# 4      20    89302        jazz

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t = movies.merge(tags, on='movieId', how='inner')
t.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId                 tag
# 0    1250               Pixar
# 1    1250         time travel
# 2    1652  computer animation
# 3    1652               funny
# 4    1652               Pixar

# %%
#ombine aggreagation, merging, and filters to get useful analytics

# %%
box_office = movies.merge(ratings, on='movieId', how='inner')
box_office.tail()
# Out:
#           movieId                       title                 genres  userId  \
# 26024284   176267           Robin Hood (1991)   Action|Drama|Romance  189131
# 26024285   176269                      Subdue         Children|Drama   97528
# 26024286   176271  Century of Birthing (2011)                  Drama     837
# 26024287   176273             Betrayal (2003)  Action|Drama|Thriller  267799
# 26024288   176275     Satan Triumphant (1917)     (no genres listed)  178373
#
#           rating
# 26024284     4.0
# 26024285     3.5
# 26024286     5.0
# 26024287     1.0
# 26024288     3.0

# %%
is_highly_rated = box_office['rating'] >= 4.0
box_office[is_highly_rated][-5:]
# Out:
#           movieId                                    title  \
# 26024274   176239  The Fat and Lean Wrestling Match (1900)
# 26024275   176245                       Deep Hearts (1981)
# 26024279   176253         St. Michael Had a Rooster (1972)
# 26024284   176267                        Robin Hood (1991)
# 26024286   176271               Century of Birthing (2011)
#
#                         genres  userId  rating
# 26024274        Comedy|Fantasy  189131     4.5
# 26024275           Documentary  106988     4.5
# 26024279    (no genres listed)  107291     4.5
# 26024284  Action|Drama|Romance  189131     4.0
# 26024286                 Drama     837     5.0

# %%
is_Adventure = box_office['genres'].str.contains('Adventure')
box_office[is_Adventure][:5]
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating
# 0       8     4.0
# 1       9     4.5
# 2      12     4.0
# 3      20     4.0
# 4      24     4.0

# %%
box_office[is_Adventure & is_highly_rated][-5:]
# Out:
#           movieId                             title  \
# 26023985   175795              Descendants 2 (2017)
# 26023986   175795              Descendants 2 (2017)
# 26023993   175795              Descendants 2 (2017)
# 26023999   175795              Descendants 2 (2017)
# 26024224   176183  The Prisoner of If Castle (1988)
#
#                                     genres  userId  rating
# 26023985  Action|Adventure|Children|Comedy   95436     5.0
# 26023986  Action|Adventure|Children|Comedy  100079     4.0
# 26023993  Action|Adventure|Children|Comedy  188339     5.0
# 26023999  Action|Adventure|Children|Comedy  251412     5.0
# 26024224                         Adventure   35192     4.0
